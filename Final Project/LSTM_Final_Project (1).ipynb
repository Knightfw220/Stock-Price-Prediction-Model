# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### User input for Stock name , start and end date and timeframe for capturing data
# #### 2 stock inputs are given to compare amongst each other

# %%
import datetime

def get_user_input():
    stock_name1 = input("Enter the first stock name (e.g., AAPL, TSLA, GOOGL): ").strip()
    stock_name2 = input("Enter the second stock name (e.g., AAPL, TSLA, GOOGL): ").strip()
    while True:
        start_date = input("Enter the start date (YYYY-MM-DD): ").strip()
        try:
            start_date = datetime.datetime.strptime(start_date, "%Y-%m-%d")
            break
        except ValueError:
            print("Invalid date format. Please enter the date in YYYY-MM-DD format.")

    while True:
        end_date = input("Enter the end date (YYYY-MM-DD): ").strip()
        try:
            end_date = datetime.datetime.strptime(end_date, "%Y-%m-%d")
            if end_date > start_date:
                break
            else:
                print("End date must be after the start date.")
        except ValueError:
            print("Invalid date format. Please enter the date in YYYY-MM-DD format.")


    timeframes = ["daily", "weekly", "monthly"]
    print(f"Available timeframes: {', '.join(timeframes)}")
    while True:
        timeframe = input("Enter the timeframe (daily/weekly/monthly): ").strip().lower()
        if timeframe in timeframes:
            break
        else:
            print("Invalid timeframe. Please choose from daily, weekly, or monthly.")

    return stock_name1, stock_name2, start_date.strftime("%Y-%m-%d"), end_date.strftime("%Y-%m-%d"), timeframe

# %%
stock_name1, stock_name2, start_date, end_date, timeframe = get_user_input()
# Out:
# Enter the first stock name (e.g., AAPL, TSLA, GOOGL): AAPL
# Enter the second stock name (e.g., AAPL, TSLA, GOOGL): GOOGL
# Enter the start date (YYYY-MM-DD): 2012-01-01
# Enter the end date (YYYY-MM-DD): 2025-01-01
# Available timeframes: daily, weekly, monthly
# Enter the timeframe (daily/weekly/monthly): daily

# %% [markdown]
# #### Import data from yfinance library for input stock

# %%
def download_historical_data(symbol, start_date, end_date, timeframe):
    timeframe_map = {
        "daily": "1d",
        "weekly": "1wk",
        "monthly": "1mo"
    }

    yf_interval = timeframe_map.get(timeframe)

    data = yf.download(tickers=symbol, start=start_date, end=end_date, interval=yf_interval)
    return data

# %% [markdown]
# ####Data for first stock

# %%
data1 = download_historical_data(stock_name1, start_date, end_date, timeframe)
data1.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2012-01-03  12.310346  12.348364  12.243590  12.255565  302220800
# 2012-01-04  12.376506  12.413627  12.251975  12.273528  260022000
# 2012-01-05  12.513906  12.529472  12.353451  12.421705  271269600
# 2012-01-06  12.644723  12.655200  12.549529  12.565993  318292800
# 2012-01-09  12.624667  12.804879  12.613291  12.737524  394024400

# %% [markdown]
# ####Data for second stock

# %%
data2 = download_historical_data(stock_name2, start_date, end_date, timeframe)
data2.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker          GOOGL      GOOGL      GOOGL      GOOGL      GOOGL
# Date
# 2012-01-03  16.505543  16.573509  16.182086  16.196224  146912940
# 2012-01-04  16.576735  16.625600  16.386727  16.496116  114445440
# 2012-01-05  16.346788  16.469822  16.277831  16.424181  131184684
# 2012-01-06  16.123796  16.371352  16.118091  16.350266  107608284
# 2012-01-09  15.440166  16.048882  15.409655  16.036479  232671096

# %% [markdown]
# ####Target column: closing stock prices

# %%
data1pred = data1['Close']
data2pred = data2['Close']

# %% [markdown]
# ####Plot closing prices

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
# Plot for the first stock
axes[0].plot(data1.index, data1['Close'], label=f'{stock_name1} Closing Price', color='green')
axes[0].plot(data1.index[-1], data1['Close'].iloc[-1], 'ro')  # Last value as a red dot
axes[0].set_title(f'{stock_name1} Closing Price Over Time')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Closing Price (USD)')
axes[0].legend()
axes[0].grid()

# Plot for the second stock
axes[1].plot(data2.index, data2['Close'], label=f'{stock_name2} Closing Price', color='blue')
axes[1].plot(data2.index[-1], data2['Close'].iloc[-1], 'ro')  # Last value as a red dot
axes[1].set_title(f'{stock_name2} Closing Price Over Time')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Closing Price (USD)')
axes[1].legend()
axes[1].grid()

plt.tight_layout()
plt.show()
# Print the last values
print(f"Last closing price for {stock_name1}: {data1['Close'].iloc[-1]}")
print(f"Last closing price for {stock_name2}: {data2['Close'].iloc[-1]}")
# Out:
# Last closing price for AAPL: Ticker
# AAPL    248.8302
# Name: 2024-12-31 00:00:00, dtype: float64
# Last closing price for GOOGL: Ticker
# GOOGL    188.316406
# Name: 2024-12-31 00:00:00, dtype: float64

# %% [markdown]
# #### Calculating a technical indicator MACD

# %%
def calculate_macd(data, short_window=12, long_window=26, signal_window=9):
    data['EMA_Short'] = data['Close'].ewm(span=short_window, adjust=False).mean()
    data['EMA_Long'] = data['Close'].ewm(span=long_window, adjust=False).mean()

    data['MACD'] = data['EMA_Short'] - data['EMA_Long']

    data['Signal_Line'] = data['MACD'].ewm(span=signal_window, adjust=False).mean()
    return data

# %% [markdown]
# #### Calculating another tachnical indicator RSI

# %%
def calculate_rsi(data, period=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
    rs = gain / loss
    data['RSI'] = 100 - (100 / (1 + rs))
    return data

# %% [markdown]
# ####Plotting MACD

# %%
def plot_macd(data1, data2, symbol1, symbol2):
    fig, axes = plt.subplots(1, 2, figsize=(20, 6))

    # Plot MACD for the first stock
    axes[0].plot(data1.index, data1['MACD'], label='MACD', color='blue')
    axes[0].plot(data1.index, data1['Signal_Line'], label='Signal Line', color='red')
    axes[0].set_title(f'{symbol1} MACD')
    axes[0].set_xlabel('Date')
    axes[0].set_ylabel('Value')
    axes[0].legend()
    axes[0].grid()

    # Plot MACD for the second stock
    axes[1].plot(data2.index, data2['MACD'], label='MACD', color='blue')
    axes[1].plot(data2.index, data2['Signal_Line'], label='Signal Line', color='red')
    axes[1].set_title(f'{symbol2} MACD')
    axes[1].set_xlabel('Date')
    axes[1].set_ylabel('Value')
    axes[1].legend()
    axes[1].grid()

    plt.tight_layout()
    plt.show()

# %%
calculate_macd(data1).head()
calculate_macd(data2).head()
plot_macd(data1, data2,stock_name1, stock_name2)

# %% [markdown]
# ####Plotting RSI

# %%
def plot_rsi(data1, data2, symbol1, symbol2):
    fig, axes = plt.subplots(1, 2, figsize=(20, 6))

    # Plot RSI for the first stock
    axes[0].plot(data1.index, data1['RSI'], label='RSI', color='purple')
    axes[0].axhline(70, color='red', linestyle='--', label='Overbought (70)')
    axes[0].axhline(30, color='green', linestyle='--', label='Oversold (30)')
    axes[0].set_title(f'{symbol1} RSI')
    axes[0].set_xlabel('Date')
    axes[0].set_ylabel('Value')
    axes[0].legend()
    axes[0].grid()

    # Plot RSI for the second stock
    axes[1].plot(data2.index, data2['RSI'], label='RSI', color='purple')
    axes[1].axhline(70, color='red', linestyle='--', label='Overbought (70)')
    axes[1].axhline(30, color='green', linestyle='--', label='Oversold (30)')
    axes[1].set_title(f'{symbol2} RSI')
    axes[1].set_xlabel('Date')
    axes[1].set_ylabel('Value')
    axes[1].legend()
    axes[1].grid()

    plt.tight_layout()
    plt.show()

# %%
calculate_rsi(data1).head()
calculate_rsi(data2).head()
plot_rsi(data1, data2, stock_name1, stock_name2)

# %% [markdown]
# ####Normalizing data for training and testing

# %%
from sklearn.preprocessing import MinMaxScaler

def normalize_data(df, columns):
    scaler = MinMaxScaler(feature_range=(0, 1))
    df[columns] = scaler.fit_transform(df[columns])
    return df, scaler

columns_to_normalize1 = ['Close', 'Volume', 'EMA_Short', 'EMA_Long', 'MACD', 'Signal_Line']
columns_to_normalize2 = ['Close', 'Volume', 'EMA_Short', 'EMA_Long', 'MACD', 'Signal_Line']

df_normalized1, scaler1 = normalize_data(data1.copy(), columns_to_normalize1)
df_normalized2, scaler2 = normalize_data(data2.copy(), columns_to_normalize2)

# %%
df_normalized1.head()
# Out:
# Price          Close       High        Low       Open    Volume EMA_Short  \
# Ticker          AAPL       AAPL       AAPL       AAPL      AAPL
# Date
# 2012-01-03  0.001821  12.348364  12.243590  12.255565  0.188137  0.000000
# 2012-01-04  0.002091  12.413627  12.251975  12.273528  0.159680  0.000043
# 2012-01-05  0.002650  12.529472  12.353451  12.421705  0.167265  0.000167
# 2012-01-06  0.003183  12.655200  12.549529  12.565993  0.198976  0.000357
# 2012-01-09  0.003101  12.804879  12.613291  12.737524  0.250046  0.000505
#
# Price       EMA_Long      MACD Signal_Line RSI
# Ticker
# Date
# 2012-01-03  0.000000  0.421800    0.406203 NaN
# 2012-01-04  0.000021  0.422144    0.406279 NaN
# 2012-01-05  0.000084  0.423123    0.406556 NaN
# 2012-01-06  0.000184  0.424555    0.407094 NaN
# 2012-01-09  0.000270  0.425541    0.407743 NaN

# %%
df_normalized2.head()
# Out:
# Price          Close       High        Low       Open    Volume EMA_Short  \
# Ticker         GOOGL      GOOGL      GOOGL      GOOGL     GOOGL
# Date
# 2012-01-03  0.014514  16.573509  16.182086  16.196224  0.282035  0.013606
# 2012-01-04  0.014906  16.625600  16.386727  16.496116  0.215488  0.013669
# 2012-01-05  0.013641  16.469822  16.277831  16.424181  0.249797  0.013520
# 2012-01-06  0.012414  16.371352  16.118091  16.350266  0.201474  0.013199
# 2012-01-09  0.008653  16.048882  15.409655  16.036479  0.457810  0.012329
#
# Price       EMA_Long      MACD Signal_Line RSI
# Ticker
# Date
# 2012-01-03  0.012898  0.463554    0.461638 NaN
# 2012-01-04  0.012929  0.464059    0.461752 NaN
# 2012-01-05  0.012858  0.462820    0.461562 NaN
# 2012-01-06  0.012695  0.460278    0.460836 NaN
# 2012-01-09  0.012247  0.453484    0.458716 NaN

# %% [markdown]
# ####Creating sequence with sliding window of past 10 days

# %%
def create_sequences(data, feature_columns, target_column, time_steps = 10):

    features = []
    targets = []
    for i in range(len(data) - time_steps):

        feature_window = data[feature_columns].iloc[i:i + time_steps].values

        target_value = data[target_column].iloc[i + time_steps]
        features.append(feature_window)
        targets.append(target_value)
    return np.array(features), np.array(targets)

# %%
time_steps = 10
if len(df_normalized1) > time_steps and len(df_normalized2) > time_steps:
        feature_columns1 = ['Close', 'Volume', 'EMA_Short', 'EMA_Long', 'MACD', 'Signal_Line']
        target_column1 = 'Close'
        feature_columns2 = ['Close', 'Volume', 'EMA_Short', 'EMA_Long', 'MACD', 'Signal_Line']
        target_column2 = 'Close'
        X1, y1 = create_sequences(df_normalized1, feature_columns1, target_column1, time_steps)
        X2, y2 = create_sequences(df_normalized2, feature_columns2, target_column2, time_steps)

else:
        print("Not enough data to create sequences. Please check the data length and time steps.")

# %% [markdown]
# ####Designing LSTM model using deep learning framework using tensorflow

# %%
def create_lstm_model(input_shape, dropout_rate=0.2):
    model = Sequential()

    model.add(LSTM(64, activation='relu', return_sequences=True, input_shape=input_shape))
    model.add(Dropout(dropout_rate))

    model.add(LSTM(64, activation='relu', return_sequences=False))
    model.add(Dropout(dropout_rate))

    model.add(Dense(1))

    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# ##Model Training
# ####Splitting data into training and tesing data

# %%
# Ensure X1 and y1 are not empty
if X1.size == 0 or y1.size == 0:
    print("X1 or y1 is empty. Please check the data preparation steps.")
else:
    # train-test split
    X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, shuffle=False)

    # Create and compile the LSTM model
    input_shape1 = (X_train1.shape[1], X_train1.shape[2])
    model1 = create_lstm_model(input_shape1)

    model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,265 (200.25 KB)
#  Trainable params: 51,265 (200.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Ensure X2 and y2 are not empty
if X2.size == 0 or y2.size == 0:
        print("X2 or y2 is empty. Please check the data preparation steps.")
else:
        # train-test split
        X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, shuffle=False)
        print(len(X_train2),len(X_test2),len(y_train2),len(y_test2))
        # Create and compile the LSTM model
        input_shape2 = (X_train2.shape[1], X_train2.shape[2])
        model2 = create_lstm_model(input_shape2)

        model2.summary()
# Out:
# 2608 652 2608 652
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 10, 64)         │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,265 (200.25 KB)
#  Trainable params: 51,265 (200.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ####Training the model

# %%
# Training the model

history1 = model1.fit(
    X_train1, y_train1,
    epochs=20,
    batch_size=32,
    validation_data=(X_test1, y_test1),
    verbose=1
)

loss, mae = model1.evaluate(X_test1, y_test1, verbose=0)
print(f"Test Loss: {loss:.4f}, Test MAE: {mae:.4f}")
# Out:
# Epoch 1/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0096 - mae: 0.0552 - val_loss: 0.0029 - val_mae: 0.0409
# Epoch 2/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - mae: 0.0209 - val_loss: 0.0021 - val_mae: 0.0357
# Epoch 3/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mae: 0.0203 - val_loss: 0.0016 - val_mae: 0.0317
# Epoch 4/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0010 - mae: 0.0192 - val_loss: 7.9110e-04 - val_mae: 0.0233
# Epoch 5/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 9.5886e-04 - mae: 0.0185 - val_loss: 6.6705e-04 - val_mae: 0.0202
# Epoch 6/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.6191e-04 - mae: 0.0165 - val_loss: 0.0014 - val_mae: 0.0313
# Epoch 7/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.5894e-04 - mae: 0.0167 - val_loss: 8.2862e-04 - val_mae: 0.0237
# Epoch 8/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.1904e-04 - mae: 0.0171 - val_loss: 0.0019 - val_mae: 0.0369
# Epoch 9/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1322e-04 - mae: 0.0149 - val_loss: 7.3780e-04 - val_mae: 0.0212
# Epoch 10/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.9367e-04 - mae: 0.0167 - val_loss: 0.0026 - val_mae: 0.0439
# Epoch 11/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.3223e-04 - mae: 0.0158 - val_loss: 7.8123e-04 - val_mae: 0.0225
# Epoch 12/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.0046e-04 - mae: 0.0152 - val_loss: 7.7732e-04 - val_mae: 0.0223
# Epoch 13/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6.3914e-04 - mae: 0.0154 - val_loss: 0.0015 - val_mae: 0.0322
# Epoch 14/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 6.6652e-04 - mae: 0.0153 - val_loss: 0.0019 - val_mae: 0.0364
# Epoch 15/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5179e-04 - mae: 0.0151 - val_loss: 0.0033 - val_mae: 0.0491
# Epoch 16/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.4959e-04 - mae: 0.0151 - val_loss: 0.0010 - val_mae: 0.0258
# Epoch 17/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.8324e-04 - mae: 0.0140 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 18/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.9535e-04 - mae: 0.0158 - val_loss: 8.5292e-04 - val_mae: 0.0234
# Epoch 19/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.9234e-04 - mae: 0.0158 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 20/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.8182e-04 - mae: 0.0141 - val_loss: 6.9048e-04 - val_mae: 0.0205
# Test Loss: 0.0007, Test MAE: 0.0205

# %%
# Training the model

history2 = model2.fit(
    X_train2, y_train2,
    epochs=20,
    batch_size=32,
    validation_data=(X_test2, y_test2),
    verbose=1
)

loss, mae = model1.evaluate(X_test2, y_test2, verbose=0)
print(f"Test Loss: {loss:.4f}, Test MAE: {mae:.4f}")
# Out:
# Epoch 1/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0095 - mae: 0.0594 - val_loss: 0.0020 - val_mae: 0.0358
# Epoch 2/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0017 - mae: 0.0263 - val_loss: 0.0032 - val_mae: 0.0416
# Epoch 3/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0013 - mae: 0.0236 - val_loss: 0.0023 - val_mae: 0.0360
# Epoch 4/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - mae: 0.0217 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 5/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - mae: 0.0219 - val_loss: 0.0010 - val_mae: 0.0254
# Epoch 6/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010 - mae: 0.0215 - val_loss: 0.0022 - val_mae: 0.0392
# Epoch 7/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mae: 0.0209 - val_loss: 0.0011 - val_mae: 0.0257
# Epoch 8/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 8.7076e-04 - mae: 0.0188 - val_loss: 0.0019 - val_mae: 0.0361
# Epoch 9/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 7.8966e-04 - mae: 0.0180 - val_loss: 8.7684e-04 - val_mae: 0.0231
# Epoch 10/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.5484e-04 - mae: 0.0181 - val_loss: 0.0016 - val_mae: 0.0322
# Epoch 11/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.3026e-04 - mae: 0.0182 - val_loss: 0.0016 - val_mae: 0.0325
# Epoch 12/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2581e-04 - mae: 0.0180 - val_loss: 0.0012 - val_mae: 0.0281
# Epoch 13/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.2895e-04 - mae: 0.0179 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 14/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9111e-04 - mae: 0.0174 - val_loss: 9.8042e-04 - val_mae: 0.0247
# Epoch 15/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.3157e-04 - mae: 0.0171 - val_loss: 0.0011 - val_mae: 0.0259
# Epoch 16/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.5838e-04 - mae: 0.0164 - val_loss: 0.0015 - val_mae: 0.0304
# Epoch 17/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0671e-04 - mae: 0.0155 - val_loss: 0.0016 - val_mae: 0.0318
# Epoch 18/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 5.9982e-04 - mae: 0.0152 - val_loss: 8.6362e-04 - val_mae: 0.0230
# Epoch 19/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9883e-04 - mae: 0.0152 - val_loss: 0.0012 - val_mae: 0.0273
# Epoch 20/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2784e-04 - mae: 0.0157 - val_loss: 0.0014 - val_mae: 0.0289
# Test Loss: 0.0009, Test MAE: 0.0234

# %% [markdown]
# Calculate R2, MAE and RMSE score for both models

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

# ---------------------- Model 1 ----------------------
y_train_pred1 = model1.predict(X_train1).flatten()

r2_1 = r2_score(y_train1, y_train_pred1)
mae_1 = mean_absolute_error(y_train1, y_train_pred1)
rmse_1 = np.sqrt(mean_squared_error(y_train1, y_train_pred1))

print("Model 1 Metrics")
print(f"R²    : {r2_1:.4f}")
print(f"MAE   : {mae_1:.4f}")
print(f"RMSE  : {rmse_1:.4f}")

# ---------------------- Model 2 ----------------------
y_train_pred2 = model2.predict(X_train2).flatten()

r2_2 = r2_score(y_train2, y_train_pred2)
mae_2 = mean_absolute_error(y_train2, y_train_pred2)
rmse_2 = np.sqrt(mean_squared_error(y_train2, y_train_pred2))

print("\nModel 2 Metrics")
print(f"R²    : {r2_2:.4f}")
print(f"MAE   : {mae_2:.4f}")
print(f"RMSE  : {rmse_2:.4f}")
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Model 1 Metrics
# R²    : 0.9959
# MAE   : 0.0084
# RMSE  : 0.0114
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Model 2 Metrics
# R²    : 0.9959
# MAE   : 0.0078
# RMSE  : 0.0119

# %% [markdown]
# ####Actual vs predicted graph for testing data

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# how to add scaler ?


# Plot for the first stock
y_test_pred1 = model1.predict(X_test1)
axes[0].plot(range(len(y_test1)), y_test1, label="Actual Values", color="blue", linestyle="--")
axes[0].plot(range(len(y_test_pred1)), y_test_pred1, label="Predicted Values", color="orange")
axes[0].set_title(f"Normalised testing Data: Actual vs. Predicted Values for {stock_name1}")
axes[0].set_xlabel("Time Steps")
axes[0].set_ylabel("Values")
axes[0].legend()

# Plot for the second stock
y_test_pred2 = model2.predict(X_test2)
axes[1].plot(range(len(y_test2)), y_test2, label="Actual Values", color="blue", linestyle="--")
axes[1].plot(range(len(y_test_pred2)), y_test_pred2, label="Predicted Values", color="orange")
axes[1].set_title(f"Normalised testing Data: Actual vs. Predicted Values for {stock_name2}")
axes[1].set_xlabel("Time Steps")
axes[1].set_ylabel("Values")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ####Training and Validation Loss

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# Plot for history1
axes[0].plot(history1.history['loss'], label='Training Loss')
axes[0].plot(history1.history['val_loss'], label='Validation Loss')
axes[0].set_title('Model 1 Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plot for history2
axes[1].plot(history2.history['loss'], label='Training Loss')
axes[1].plot(history2.history['val_loss'], label='Validation Loss')
axes[1].set_title('Model 2 Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

# Plot for history1
axes[0].plot(history1.history['mae'], label='Training MAE')
axes[0].plot(history1.history['val_mae'], label='Validation MAE')
axes[0].set_title('Model 1 MAE')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Mean Absolute Error')
axes[0].legend()

# Plot for history2
axes[1].plot(history2.history['mae'], label='Training MAE')
axes[1].plot(history2.history['val_mae'], label='Validation MAE')
axes[1].set_title('Model 2 MAE')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Mean Absolute Error')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Predict values for next 1 year

# %% [markdown]
# ####Plot predicted vs market data starting from the ending period upto 1 year

# %%
from datetime import datetime

# fet future data from yfinance for 1 year
start_date = datetime(2025,1, 1)
end_date = datetime(2026,1, 1)
future_data1 = download_historical_data("GOOGL", start_date.strftime("%Y-%m-%d"), end_date.strftime("%Y-%m-%d"), "daily")
future_data2 = download_historical_data("AAPL", start_date.strftime("%Y-%m-%d"), end_date.strftime("%Y-%m-%d"), "daily")

# add macd, rsi technical indicators to data
future_data1 = calculate_macd(future_data1)
future_data1 = calculate_macd(future_data2)
future_data2 = calculate_rsi(future_data1)
future_data2 = calculate_rsi(future_data2)

# normalise data
df_normalized_future1, scaler1 = normalize_data(future_data1.copy(), columns_to_normalize1)
df_normalized_future2, scaler2 = normalize_data(future_data2.copy(), columns_to_normalize2)

# model predictions
X_future1, y_future1 = create_sequences(df_normalized_future1, feature_columns1, target_column1, time_steps)
X_future2, y_future2 = create_sequences(df_normalized_future2, feature_columns2, target_column2, time_steps)

y_future_pred1 = model1.predict(X_future1)
y_future_pred2 = model2.predict(X_future2)

# Plot
fig, axes = plt.subplots(1, 2, figsize=(20, 6))

axes[0].plot(range(len(y_future1)), y_future1, label="Actual Values", color="blue", linestyle="--")
axes[0].plot(range(len(y_future_pred1)), y_future_pred1, label="Predicted Values", color="orange")
axes[0].set_title(f"Normalised future testing Data: Actual vs. Predicted Values for {stock_name1}")
axes[0].set_xlabel("Time Steps")
axes[0].set_ylabel("Values")
axes[0].legend()

axes[1].plot(range(len(y_future2)), y_future2, label="Actual Values", color="blue", linestyle="--")
axes[1].plot(range(len(y_future_pred2)), y_future_pred2, label="Predicted Values", color="orange")
axes[1].set_title(f"Normalised future testing Data: Actual vs. Predicted Values for {stock_name2}")
axes[1].set_xlabel("Time Steps")
axes[1].set_ylabel("Values")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
import numpy as np

def sharpe_ratio(prices, risk_free_rate=0.05, trading_days=252):
    prices = np.asarray(prices).flatten()

    returns = np.diff(prices) / prices[:-1]

    daily_rf = risk_free_rate / trading_days

    excess_returns = returns - daily_rf

    sharpe = np.sqrt(trading_days) * np.mean(excess_returns) / np.std(excess_returns)

    return sharpe

# %%
from sklearn.preprocessing import MinMaxScaler

close_scaler1 = MinMaxScaler()
close_scaler1.fit(future_data1[['Close']])

close_scaler2 = MinMaxScaler()
close_scaler2.fit(future_data2[['Close']])

# Denormalise before calculating sharpe ratio
y_future1_inv = close_scaler1.inverse_transform(
    y_future1.reshape(-1,1)
).flatten()

y_future_pred1_inv = close_scaler1.inverse_transform(
    y_future_pred1.reshape(-1,1)
).flatten()

y_future2_inv = close_scaler2.inverse_transform(
    y_future2.reshape(-1,1)
).flatten()

y_future_pred2_inv = close_scaler2.inverse_transform(
    y_future_pred2.reshape(-1,1)
).flatten()

actual_sharpe1 = sharpe_ratio(y_future1_inv, risk_free_rate=0.05)
predicted_sharpe1 = sharpe_ratio(y_future_pred1_inv, risk_free_rate=0.05)

actual_sharpe2 = sharpe_ratio(y_future2_inv, risk_free_rate=0.05)
predicted_sharpe2 = sharpe_ratio(y_future_pred2_inv, risk_free_rate=0.05)

print(f"{stock_name1} Actual Sharpe Ratio     : {actual_sharpe1:.4f}")
print(f"{stock_name1} Predicted Sharpe Ratio  : {predicted_sharpe1:.4f}")
print(f"{stock_name2} Actual Sharpe Ratio     : {actual_sharpe2:.4f}")
print(f"{stock_name2} Predicted Sharpe Ratio  : {predicted_sharpe2:.4f}")
# Out:
# AAPL Actual Sharpe Ratio     : 0.5635
# AAPL Predicted Sharpe Ratio  : 1.2922
# GOOGL Actual Sharpe Ratio     : 0.5635
# GOOGL Predicted Sharpe Ratio  : 1.4374
